# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString
from shapely import wkt
import numpy as np
import cv2
import os
import math
import matplotlib.pyplot as plt
import string # For filename suffixes

# --- Configuration Parameters ---
INPUT_GEOJSON = '../data/Street_view/Preprocessed_to_use_for_picture_extraction.geojson'
OUTPUT_GEOJSON = 'data/Street_view/Preprocessed_with_filenames_REVISED.geojson'
IMAGES_BASE_FOLDER = '../data/PANO_new/'
OUTPUT_IMAGES_FOLDER = '../data/Street_view/Output_images_REVISED/'

# Camera/Targeting Settings
CAMERA_HEIGHT_OFFSET = 0.0 # Assume Z in GeoJSON is camera height. Adjust if Z is ground.
TARGET_Z_OFFSET = 0.25 # How much higher than camera Z to aim at the target (e.g., slightly above midpoint)
PITCH_OFFSET_DEG = 0.0 # Additional pitch angle (DEGREES). KEEP SMALL (0-5). Avoid large values like 25!

# FoV Calculation Settings
FOV_PADDING_FACTOR = 1.15 # Multiplier for calculated FoV (1.1 = 10% padding)
MIN_FOV_DEG = 50.0 # Minimum allowed horizontal FoV
MAX_FOV_DEG = 100.0 # Maximum allowed horizontal FoV

# Filtering Settings
MIN_DISTANCE_M = 3.0 # Minimum distance from camera to facade target point
MAX_DISTANCE_M = 25.0 # Maximum distance (facades further than this are likely low-res)
FILTER_BY_VIEW_ANGLE = True # Enable filtering based on viewing angle?
MAX_VIEW_ANGLE_DEG = 60.0 # Maximum angle (degrees) between view vector and facade normal (0=fronto-parallel)

# Output Image Settings
OUTPUT_WIDTH = 1024 # Desired width of the output perspective image
OUTPUT_HEIGHT = 1024 # Desired height
OUTPUT_UPSCALE_FACTOR = 1 # Factor to increase internal rendering resolution (1=no upscale, 2=render at 2x then downscale - slower but smoother)

# --- Helper Functions ---

def calculate_yaw_pitch(camera_pos_3d, target_pos_3d):
    """Calculates Yaw (Azimuth) and Pitch (Elevation) from camera to target.

    Args:
        camera_pos_3d (tuple): (x, y, z) of the camera.
        target_pos_3d (tuple): (x, y, z) of the target point.

    Returns:
        tuple: (yaw_deg, pitch_deg)
               Yaw: Angle in degrees [0, 360], relative to the coordinate system's
                    positive X-axis (adjust if needed based on panorama format).
               Pitch: Angle in degrees [-90, 90], relative to the XY plane.
    """
    x1, y1, z1 = camera_pos_3d
    x2, y2, z2 = target_pos_3d

    dx = x2 - x1
    dy = y2 - y1
    dz = z2 - z1

    horizontal_distance = math.sqrt(dx**2 + dy**2)

    if horizontal_distance < 1e-6: # Avoid division by zero if target is directly above/below
        print("Warning: Camera and target X,Y are virtually identical.")
        yaw_deg = 0 # Yaw is undefined, default to 0
        pitch_deg = 90 if dz >= 0 else -90
    else:
        # Yaw: Angle in the XY plane. Using atan2(dy, dx) gives angle relative to +X axis.
        # Check if your panorama theta=0 corresponds to +X (East) or +Y (North).
        # The original used atan2(-dy, -dx) which is angle relative to -X axis + 180 deg.
        # Let's use atan2(dy, dx) assuming theta=0 is East (+X). Adjust if needed.
        yaw_rad = math.atan2(dy, dx)
        yaw_deg = math.degrees(yaw_rad)
        yaw_deg = (yaw_deg + 360) % 360 # Ensure range [0, 360]

        # Pitch: Angle relative to the horizontal plane.
        pitch_rad = math.atan2(dz, horizontal_distance)
        pitch_deg = math.degrees(pitch_rad)

    return yaw_deg, pitch_deg

def enhanced_equirectangular_to_perspective(img, fov_deg, yaw_deg, pitch_deg, roll_deg,
                                            out_height, out_width, output_scale=1):
    """Warps an equirectangular image to a perspective view.

    Args:
        img: Input equirectangular image (numpy array, HxWxC).
        fov_deg: Desired horizontal field of view (degrees).
        yaw_deg: Center view direction yaw (azimuth, degrees).
        pitch_deg: Center view direction pitch (elevation, degrees).
        roll_deg: View rotation around the viewing axis (degrees).
        out_height: Desired output height in pixels.
        out_width: Desired output width in pixels.
        output_scale: Factor to upscale rendering resolution for anti-aliasing.

    Returns:
        Numpy array: The perspective image.
    """
    fov_rad, yaw_rad, pitch_rad, roll_rad = map(np.radians, (fov_deg, yaw_deg, pitch_deg, roll_deg))

    in_h, in_w = img.shape[:2]

    # Render at higher resolution if output_scale > 1
    render_width = out_width * output_scale
    render_height = out_height * output_scale

    # Calculate focal length from FoV and render width
    focal_length = render_width / (2 * np.tan(fov_rad / 2))

    # --- 3D Rotation Setup ---
    # Rotation order: Roll -> Pitch -> Yaw (applied to camera frame)
    # Or equivalently: -Yaw -> -Pitch -> -Roll (applied to world points)
    # We map output pixels (camera frame) to world directions, then to panorama coords.

    # Rotation matrices (using scipy/transforms3d might be cleaner, but numpy is fine)
    # Note: Positive pitch looks up, positive yaw turns left (if theta=0 is North) or right (if theta=0 is East). Check convention.
    # Assuming yaw increases counter-clockwise from +X axis (East)
    # Assuming pitch increases upwards from XY plane
    # Assuming roll increases counter-clockwise around viewing axis

    # Rz(roll) rotates around viewing axis (initially Z)
    # Rx(pitch) rotates around camera's X axis
    # Ry(yaw) rotates around camera's Y axis
    # Let's use ZYX convention for Tait-Bryan angles (Yaw around Z, Pitch around Y, Roll around X)
    # Adjust based on exact definition of yaw, pitch, roll in your system/panorama.
    # If yaw is azimuth (around Z), pitch is elevation (around Y'), roll is around X''

    cy, sy = np.cos(yaw_rad), np.sin(yaw_rad)
    cp, sp = np.cos(pitch_rad), np.sin(pitch_rad)
    cr, sr = np.cos(roll_rad), np.sin(roll_rad)

    # Rotation matrix: camera coordinates -> world coordinates
    # Assuming initial camera looks along +X, Y is left, Z is up. Rotate to target.
    # R = R_z(yaw) @ R_y(pitch) @ R_x(roll)  -- check this order matches your system
    # If yaw is around vertical (Z), pitch around horizontal (Y'), roll around view (X'')
    R_yaw = np.array([[cy, -sy, 0], [sy, cy, 0], [0, 0, 1]]) # Rotation around Z
    R_pitch = np.array([[cp, 0, sp], [0, 1, 0], [-sp, 0, cp]]) # Rotation around Y
    R_roll = np.array([[1, 0, 0], [0, cr, -sr], [0, sr, cr]]) # Rotation around X

    # Combined rotation: first roll, then pitch, then yaw
    R = R_yaw @ R_pitch @ R_roll
    # If initial camera looks along +Z, Y is right, X is down (OpenGL style): adjust R

    # --- Map Output Pixels to Panorama ---
    # Create grid of pixel coordinates in the output image (rendering resolution)
    y_render, x_render = np.indices((render_height, render_width), dtype=np.float32)

    # Center and scale pixels to represent normalized coordinates on the image plane
    x_cam = (x_render - render_width / 2) / focal_length
    y_cam = (y_render - render_height / 2) / focal_length # Y points downwards in image coords usually
    z_cam = np.ones_like(x_cam) # Assume image plane at z=1

    # Create 3D direction vectors in the camera's coordinate system
    # If camera looks along +X: directions = [z_cam, x_cam, -y_cam] ? Check axis definitions
    # Assuming standard computer vision camera: +X right, +Y down, +Z forward
    directions_cam = np.stack([x_cam, y_cam, z_cam], axis=-1)

    # Normalize direction vectors
    directions_cam /= np.linalg.norm(directions_cam, axis=2, keepdims=True)

    # Rotate direction vectors from camera frame to world frame using transpose (inverse) of R
    # directions_world = directions_cam @ R.T # Check if R maps world->cam or cam->world
    # Let's assume R maps *world axes* to *camera axes*. To rotate *camera vector* to *world vector*, use R.T
    # If R maps *camera axes* to *world axes*, use R directly. Let's try R.T
    directions_world = np.einsum('ijk,lk->ijl', directions_cam, R) # Efficient matrix multiplication for batches

    # --- Convert World Directions to Panorama Spherical Coordinates ---
    # Assuming panorama coords: theta=azimuth (0 at +X?), phi=elevation (0 at horizon?)
    x_world = directions_world[:, :, 0]
    y_world = directions_world[:, :, 1]
    z_world = directions_world[:, :, 2]

    # Theta (Azimuth): Use atan2(y, x) for angle from +X axis. Adjust if needed.
    theta_pano = np.arctan2(y_world, x_world) # Radians in [-pi, pi]

    # Phi (Elevation): Use asin(z / radius). Radius is 1 since directions are normalized.
    phi_pano = np.arcsin(np.clip(z_world, -1.0, 1.0)) # Radians in [-pi/2, pi/2]

    # --- Map Spherical Coordinates to Equirectangular Pixel Coordinates ---
    # u: horizontal pixel coord (0 to in_w). theta=0 -> u=in_w/2 ? theta=-pi -> u=0?
    # Assuming theta=0 at center (+X), theta ranges [-pi, pi] maps to [0, in_w]
    u = (theta_pano / (2 * np.pi) + 0.5) * in_w # Maps [-pi, pi] to [0, in_w]

    # v: vertical pixel coord (0 to in_h). phi=pi/2 -> v=0? phi=-pi/2 -> v=in_h?
    # Assuming phi=pi/2 (North Pole) at v=0, phi=-pi/2 (South Pole) at v=in_h
    v = (-phi_pano / np.pi + 0.5) * in_h # Maps [pi/2, -pi/2] to [0, in_h]

    # --- Sample Pixels using Bilinear Interpolation ---
    # (Using cv2.remap is often faster and handles boundaries better)
    map_x = u.astype(np.float32)
    map_y = v.astype(np.float32)

    # cv2.remap expects map_x, map_y with dimensions (out_H, out_W)
    # Interpolation method
    interpolator = cv2.INTER_LINEAR

    # Use cv2.remap for potentially faster interpolation
    output_render = cv2.remap(img, map_x, map_y,
                              interpolation=interpolator,
                              borderMode=cv2.BORDER_WRAP) # Use WRAP for 360 images

    # Downscale if rendered at higher resolution
    if output_scale > 1:
        output_image = cv2.resize(output_render, (out_width, out_height), interpolation=cv2.INTER_AREA)
    else:
        output_image = output_render

    return output_image.astype(np.uint8) # Ensure output is uint8

def project_point_onto_segment(point_xy, seg_start_xy, seg_end_xy):
    """Projects a 2D point onto a 2D line segment."""
    point = np.array(point_xy)
    start = np.array(seg_start_xy)
    end = np.array(seg_end_xy)

    line_vec = end - start
    point_vec = point - start

    line_len_sq = np.dot(line_vec, line_vec)
    if line_len_sq < 1e-9: # Segment is a point
        return start

    t = np.dot(point_vec, line_vec) / line_len_sq
    t = np.clip(t, 0, 1) # Clamp projection to the segment

    projected_point = start + t * line_vec
    return projected_point

def calculate_facade_normal(facade_segment):
    """Estimates the 2D normal vector of a facade LineString (pointing outwards)."""
    coords = list(facade_segment.coords)
    if len(coords) < 2:
        return None # Cannot calculate normal for a point

    # Use the first segment for direction (or average if needed)
    p1 = np.array(coords[0][:2])
    p2 = np.array(coords[1][:2])

    # Direction vector along the facade
    dir_vec = p2 - p1
    dir_vec_norm = np.linalg.norm(dir_vec)
    if dir_vec_norm < 1e-6:
        return None # Segment too short

    # Normalized direction vector
    dir_vec = dir_vec / dir_vec_norm

    # Normal vector (rotate 90 degrees) - potential ambiguity in direction (in/out)
    # Option 1: Rotate counter-clockwise
    normal_vec = np.array([-dir_vec[1], dir_vec[0]])
    # Option 2: Rotate clockwise
    # normal_vec = np.array([dir_vec[1], -dir_vec[0]])

    # We need a heuristic to determine outwards normal, maybe based on building polygon centroid?
    # For now, just return one possibility. Assuming OSM polygon winding order might help.
    return normal_vec # Needs check for outwards direction if critical

def calculate_geometric_fov(facade_length, distance, padding_factor=1.1, min_fov=60.0, max_fov=100.0):
    """Calculates horizontal FoV needed to capture facade based on distance and length."""
    if distance < 1e-3:
        return max_fov # Very close, use max FoV

    # Angle subtended by half the facade length
    angle_half_facade = math.atan((facade_length / 2.0) / distance)

    # Full angle needed for the facade
    fov_rad = 2 * angle_half_facade

    # Apply padding
    fov_rad *= padding_factor

    fov_deg = math.degrees(fov_rad)

    # Clamp to min/max limits
    fov_deg_clamped = np.clip(fov_deg, min_fov, max_fov)

    return fov_deg_clamped

def convert_bgr_to_rgb(image):
    """Converts BGR image (from cv2.imread) to RGB."""
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# --- Main Processing Logic ---

print(f"Loading GeoJSON: {INPUT_GEOJSON}")
try:
    gdf_combined = gpd.read_file(INPUT_GEOJSON)
except Exception as e:
    print(f"Error loading GeoJSON: {e}")
    exit()

# Prepare geometry columns (handle potential errors)
try:
    if 'midpoint_x' in gdf_combined.columns and 'midpoint_y' in gdf_combined.columns:
        gdf_combined['geometry_midpoint'] = gdf_combined.apply(
            lambda row: Point(row['midpoint_x'], row['midpoint_y']), axis=1
        )
    else:
        print("Warning: 'midpoint_x' or 'midpoint_y' columns not found.")
        # Attempt to calculate from 'geometry_outer_edge' if midpoint missing
        if 'geometry_outer_edge' in gdf_combined.columns:
             gdf_combined['geometry_outer_edge_shapely'] = gdf_combined['geometry_outer_edge'].apply(wkt.loads)
             gdf_combined['geometry_midpoint'] = gdf_combined['geometry_outer_edge_shapely'].centroid
        else:
             raise ValueError("Cannot determine midpoint.")

    if 'geometry_outer_edge' in gdf_combined.columns and not isinstance(gdf_combined['geometry_outer_edge'].iloc[0], LineString):
         gdf_combined['geometry_outer_edge_shapely'] = gdf_combined['geometry_outer_edge'].apply(wkt.loads)
    elif 'geometry_outer_edge_shapely' not in gdf_combined.columns:
         raise ValueError("'geometry_outer_edge' column missing or not WKT.")
    else:
         # If already shapely objects, ensure correct column name
         if 'geometry_outer_edge_shapely' not in gdf_combined.columns:
             gdf_combined.rename(columns={'geometry_outer_edge': 'geometry_outer_edge_shapely'}, inplace=True)


except Exception as e:
    print(f"Error preparing geometry columns: {e}")
    exit()


print(f"Outputting images to: {OUTPUT_IMAGES_FOLDER}")
os.makedirs(OUTPUT_IMAGES_FOLDER, exist_ok=True)

# Dictionary to track image counts per building for naming
building_image_count = {}
output_filenames_list = []

print("Starting perspective image extraction...")
for i, row in gdf_combined.iterrows():
    try:
        print(f"\nProcessing row {i} (Building ID: {row.get('building_id', 'N/A')}, OSM ID: {row.get('osm_id', 'N/A')})")

        # --- 1. Get Inputs ---
        cam_x, cam_y, cam_z = row['X'], row['Y'], row['Z'] + CAMERA_HEIGHT_OFFSET
        roll_deg = row['Roll']
        facade_line = row['geometry_outer_edge_shapely']
        facade_midpoint_geom = row['geometry_midpoint']

        if not isinstance(facade_line, LineString) or len(facade_line.coords) < 2:
             print("Skipping: Invalid facade geometry.")
             output_filenames_list.append(None)
             continue

        facade_start_xy = facade_line.coords[0][:2]
        facade_end_xy = facade_line.coords[-1][:2]
        facade_length = facade_line.length

        # --- 2. Determine Target Point ---
        cam_xy = (cam_x, cam_y)
        projected_target_xy = project_point_onto_segment(cam_xy, facade_start_xy, facade_end_xy)

        # Choose target point (e.g., projected point)
        target_x, target_y = projected_target_xy
        target_z = cam_z + TARGET_Z_OFFSET # Aim slightly higher than camera

        camera_pos_3d = (cam_x, cam_y, cam_z)
        target_pos_3d = (target_x, target_y, target_z)

        # --- 3. Calculate Distance and Basic Filtering ---
        dist_xy = math.sqrt((target_x - cam_x)**2 + (target_y - cam_y)**2)
        print(f"  Distance (XY): {dist_xy:.2f}m")

        if not (MIN_DISTANCE_M <= dist_xy <= MAX_DISTANCE_M):
            print(f"Skipping: Distance {dist_xy:.2f}m out of range [{MIN_DISTANCE_M}, {MAX_DISTANCE_M}].")
            output_filenames_list.append(None)
            continue

        # --- 4. View Angle Filtering (Optional) ---
        if FILTER_BY_VIEW_ANGLE:
            facade_normal_vec = calculate_facade_normal(facade_line)
            if facade_normal_vec is not None:
                view_vec_xy = np.array([target_x - cam_x, target_y - cam_y])
                view_vec_norm = np.linalg.norm(view_vec_xy)

                if view_vec_norm > 1e-6:
                    view_vec_xy /= view_vec_norm # Normalize

                    # Dot product between normalized view vector and facade normal
                    # Use absolute value as normal direction might be ambiguous
                    cos_angle = abs(np.dot(view_vec_xy, facade_normal_vec))
                    angle_deg = math.degrees(np.arccos(np.clip(cos_angle, 0, 1))) # Angle is between view and normal line (90=parallel)
                    view_angle_to_normal = 90.0 - angle_deg # Angle between view and facade plane (0=parallel, 90=perpendicular)

                    # We want angle between view vector and *normal* to be small
                    angle_check = angle_deg # This is angle between view vector and the normal vector

                    print(f"  View Angle to Facade Normal: {angle_check:.2f} deg")
                    if angle_check > MAX_VIEW_ANGLE_DEG:
                        print(f"Skipping: View angle {angle_check:.2f} deg > {MAX_VIEW_ANGLE_DEG} deg (too oblique).")
                        output_filenames_list.append(None)
                        continue
            else:
                print("  Warning: Could not calculate facade normal for angle check.")


        # --- 5. Calculate View Parameters (Yaw, Pitch, FoV) ---
        yaw_deg, pitch_deg_raw = calculate_yaw_pitch(camera_pos_3d, target_pos_3d)
        pitch_deg = pitch_deg_raw + PITCH_OFFSET_DEG # Apply small offset if desired
        print(f"  Calculated Yaw: {yaw_deg:.2f}, Raw Pitch: {pitch_deg_raw:.2f}, Final Pitch: {pitch_deg:.2f}")

        fov_deg = calculate_geometric_fov(facade_length, dist_xy, FOV_PADDING_FACTOR, MIN_FOV_DEG, MAX_FOV_DEG)
        print(f"  Facade Length: {facade_length:.2f}m, Calculated FoV: {fov_deg:.2f} deg")

        # --- 6. Load Panorama Image ---
        path_val = row['PATH']
        run_val = row['RUN']
        foto_val = row['FOTO']
        image_path = os.path.join(IMAGES_BASE_FOLDER, str(path_val), str(run_val), str(foto_val))

        if not os.path.exists(image_path):
            print(f"Skipping: Image not found at {image_path}")
            output_filenames_list.append(None)
            continue

        panorama_image_bgr = cv2.imread(image_path)
        if panorama_image_bgr is None:
             print(f"Skipping: Failed to load image {image_path}")
             output_filenames_list.append(None)
             continue
        panorama_image_rgb = convert_bgr_to_rgb(panorama_image_bgr)
        print(f"  Loaded image: {image_path}")

        # --- 7. Extract Perspective Image ---
        output_image = enhanced_equirectangular_to_perspective(
            panorama_image_rgb,
            fov_deg, yaw_deg, pitch_deg, roll_deg,
            OUTPUT_HEIGHT, OUTPUT_WIDTH, OUTPUT_UPSCALE_FACTOR
        )

        # --- 8. Save Output Image ---
        building_id = str(row.get('building_id', f'Idx_{i}')) # Use index if ID missing
        if building_id not in building_image_count:
            building_image_count[building_id] = 0

        building_image_count[building_id] += 1
        suffix = ''
        # Append letter only if it's the second, third, etc., image for this building ID
        if building_image_count[building_id] > 1:
            # Map count 2->A, 3->B, etc.
            suffix = string.ascii_uppercase[building_image_count[building_id] - 2]

        output_filename = f"Building_{building_id}{suffix}.png"
        output_path = os.path.join(OUTPUT_IMAGES_FOLDER, output_filename)

        print(f"  Saving perspective image to: {output_path}")
        saved = plt.imsave(output_path, output_image)
        # Alternative save using OpenCV (might be faster, check color order)
        # saved = cv2.imwrite(output_path, cv2.cvtColor(output_image, cv2.COLOR_RGB2BGR))

        if not saved: # Check if saving failed (though plt.imsave doesn't return bool)
             print(f"  Warning: Failed to save image {output_path}")
             output_filenames_list.append(None)
        else:
             output_filenames_list.append(output_filename)

        # Optional: Display results for debugging
        # plt.imshow(output_image)
        # plt.title(f"Bldg {building_id}{suffix} - Dist:{dist_xy:.1f}m, Ang:{angle_check:.1f}, FoV:{fov_deg:.1f}")
        # plt.axis('off')
        # plt.show()
        # plt.close('all') # Close plot window

    except Exception as e:
        print(f"!!!!!!!! ERROR processing row {i}: {e} !!!!!!!!!!")
        import traceback
        traceback.print_exc() # Print detailed traceback
        output_filenames_list.append(None)
        continue # Continue to the next row

# --- Final Step: Update GeoDataFrame and Save ---
print("\nUpdating GeoDataFrame with output filenames...")
# Ensure the list length matches the DataFrame length
if len(output_filenames_list) != len(gdf_combined):
     print(f"Error: Length mismatch between results ({len(output_filenames_list)}) and GeoDataFrame ({len(gdf_combined)}). Saving skipped.")
else:
     gdf_combined['output_filename_revised'] = output_filenames_list

     # Drop temporary geometry columns if they exist
     if 'geometry_midpoint' in gdf_combined.columns:
         gdf_combined = gdf_combined.drop(columns=['geometry_midpoint'])
     if 'geometry_outer_edge_shapely' in gdf_combined.columns:
         # Decide if you want to keep the shapely version or the original WKT
         # Let's drop the temporary shapely one if the original WKT exists
         if 'geometry_outer_edge' in gdf_combined.columns:
              gdf_combined = gdf_combined.drop(columns=['geometry_outer_edge_shapely'])
         else: # Otherwise, maybe rename it if needed?
              pass # gdf_combined.rename(columns={'geometry_outer_edge_shapely': 'geometry'}, inplace=True)


     # Make sure a valid geometry column is set if needed for saving
     if 'geometry' not in gdf_combined.columns and 'geometry_outer_edge_shapely' in gdf_combined.columns:
          gdf_combined = gdf_combined.set_geometry('geometry_outer_edge_shapely')
     elif 'geometry' not in gdf_combined.columns and 'geometry_midpoint' in gdf_combined.columns:
          gdf_combined = gdf_combined.set_geometry('geometry_midpoint')
     # Add more logic if necessary to ensure 'geometry' column exists/is set

     print(f"Saving updated GeoDataFrame to: {OUTPUT_GEOJSON}")
     try:
         # Ensure geometry is set before saving
         if 'geometry' not in gdf_combined.columns:
              print("Warning: No active geometry column set in GeoDataFrame. Saving might fail or lack geometry.")
              # Attempt to set one if possible, e.g., from original input if it exists
              # gdf_combined = gdf_combined.set_geometry('original_geometry_column_name')

         gdf_combined.to_file(OUTPUT_GEOJSON, driver='GeoJSON')
         print("GeoDataFrame saved successfully.")
     except Exception as e:
         print(f"Error saving updated GeoJSON: {e}")

print("\nProcessing finished.")
# Out:
# Loading GeoJSON: ../data/Street_view/Preprocessed_to_use_for_picture_extraction.geojson
# Outputting images to: ../data/Street_view/Output_images_REVISED/
# Starting perspective image extraction...
#
# Processing row 0 (Building ID: 34, OSM ID: 182136815)
#   Distance (XY): 2.61m
# Skipping: Distance 2.61m out of range [3.0, 25.0].
#
# Processing row 1 (Building ID: 76, OSM ID: 182137529)
#   Distance (XY): 2.63m
# Skipping: Distance 2.63m out of range [3.0, 25.0].
#
# Processing row 2 (Building ID: 123, OSM ID: 182138139)
#   Distance (XY): 3.15m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 61.61, Raw Pitch: 4.54, Final Pitch: 4.54
#   Facade Length: 5.40m, Calculated FoV: 93.43 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000045.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_123.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_123.png
#
# Processing row 3 (Building ID: 12, OSM ID: 182136647)
#   Distance (XY): 3.61m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 62.35, Raw Pitch: 3.97, Final Pitch: 3.97
#   Facade Length: 7.27m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000047.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_12.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_12.png
#
# Processing row 4 (Building ID: 12, OSM ID: 182136647)
#   Distance (XY): 3.71m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 70.63, Raw Pitch: 3.86, Final Pitch: 3.86
#   Facade Length: 3.78m, Calculated FoV: 62.13 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000049.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_12A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_12A.png
#
# Processing row 5 (Building ID: 116, OSM ID: 182137984)
#   Distance (XY): 3.51m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 71.46, Raw Pitch: 4.07, Final Pitch: 4.07
#   Facade Length: 5.86m, Calculated FoV: 91.63 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000050.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_116.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_116.png
#
# Processing row 6 (Building ID: 167, OSM ID: 2427045)
#   Distance (XY): 2.91m
# Skipping: Distance 2.91m out of range [3.0, 25.0].
#
# Processing row 7 (Building ID: 64, OSM ID: 182137239)
#   Distance (XY): 2.86m
# Skipping: Distance 2.86m out of range [3.0, 25.0].
#
# Processing row 8 (Building ID: 180, OSM ID: 2427080)
#   Distance (XY): 2.91m
# Skipping: Distance 2.91m out of range [3.0, 25.0].
#
# Processing row 9 (Building ID: 6, OSM ID: 182136604)
#   Distance (XY): 7.42m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.75, Raw Pitch: 1.93, Final Pitch: 1.93
#   Facade Length: 7.93m, Calculated FoV: 64.70 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000069.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_6.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_6.png
#
# Processing row 10 (Building ID: 4, OSM ID: 182136595)
#   Distance (XY): 7.12m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.76, Raw Pitch: 2.01, Final Pitch: 2.01
#   Facade Length: 14.45m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000066.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_4.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_4.png
#
# Processing row 11 (Building ID: 135, OSM ID: 182138240)
#   Distance (XY): 7.13m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.58, Raw Pitch: 2.01, Final Pitch: 2.01
#   Facade Length: 7.87m, Calculated FoV: 66.43 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000062.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_135.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_135.png
#
# Processing row 12 (Building ID: 121, OSM ID: 182138083)
#   Distance (XY): 7.16m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.71, Raw Pitch: 2.00, Final Pitch: 2.00
#   Facade Length: 4.33m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000060.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_121.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_121.png
#
# Processing row 13 (Building ID: 5, OSM ID: 182136600)
#   Distance (XY): 7.10m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.60, Raw Pitch: 2.02, Final Pitch: 2.02
#   Facade Length: 7.54m, Calculated FoV: 64.33 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000058.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_5.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_5.png
#
# Processing row 14 (Building ID: 111, OSM ID: 182137955)
#   Distance (XY): 7.02m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.22, Raw Pitch: 2.04, Final Pitch: 2.04
#   Facade Length: 3.87m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000056.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_111.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_111.png
#
# Processing row 15 (Building ID: 108, OSM ID: 182137941)
#   Distance (XY): 6.93m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.82, Raw Pitch: 2.07, Final Pitch: 2.07
#   Facade Length: 6.72m, Calculated FoV: 59.50 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000054.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_108.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_108.png
#
# Processing row 16 (Building ID: 107, OSM ID: 182137940)
#   Distance (XY): 6.92m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.27, Raw Pitch: 2.07, Final Pitch: 2.07
#   Facade Length: 3.88m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000053.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_107.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_107.png
#
# Processing row 17 (Building ID: 93, OSM ID: 182137728)
#   Distance (XY): 6.94m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.41, Raw Pitch: 2.06, Final Pitch: 2.06
#   Facade Length: 4.27m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000051.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_93.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_93.png
#
# Processing row 18 (Building ID: 168, OSM ID: 2427048)
#   Distance (XY): 6.91m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.59, Raw Pitch: 2.07, Final Pitch: 2.07
#   Facade Length: 8.94m, Calculated FoV: 75.64 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000049.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_168.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_168.png
#
# Processing row 19 (Building ID: 100, OSM ID: 182137837)
#   Distance (XY): 6.85m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.22, Raw Pitch: 2.09, Final Pitch: 2.09
#   Facade Length: 3.52m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000047.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_100.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_100.png
#
# Processing row 20 (Building ID: 34, OSM ID: 182136815)
#   Distance (XY): 6.88m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.31, Raw Pitch: 2.08, Final Pitch: 2.08
#   Facade Length: 11.15m, Calculated FoV: 89.80 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000045.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_34.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_34.png
#
# Processing row 21 (Building ID: 16, OSM ID: 182136664)
#   Distance (XY): 6.95m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.36, Raw Pitch: 2.06, Final Pitch: 2.06
#   Facade Length: 4.65m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000042.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_16.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_16.png
#
# Processing row 22 (Building ID: 15, OSM ID: 182136662)
#   Distance (XY): 6.88m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.63, Raw Pitch: 2.08, Final Pitch: 2.08
#   Facade Length: 5.83m, Calculated FoV: 52.78 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000040.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_15.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_15.png
#
# Processing row 23 (Building ID: 165, OSM ID: 2427037)
#   Distance (XY): 6.81m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.29, Raw Pitch: 2.10, Final Pitch: 2.10
#   Facade Length: 6.11m, Calculated FoV: 55.58 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000038.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_165.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_165.png
#
# Processing row 24 (Building ID: 14, OSM ID: 182136652)
#   Distance (XY): 6.81m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.30, Raw Pitch: 2.10, Final Pitch: 2.10
#   Facade Length: 10.02m, Calculated FoV: 83.60 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000036.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_14.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_14.png
#
# Processing row 25 (Building ID: 28, OSM ID: 182136749)
#   Distance (XY): 6.68m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.62, Raw Pitch: 2.14, Final Pitch: 2.14
#   Facade Length: 14.11m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000032.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_28.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_28.png
#
# Processing row 26 (Building ID: 102, OSM ID: 182137892)
#   Distance (XY): 6.66m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.59, Raw Pitch: 2.15, Final Pitch: 2.15
#   Facade Length: 6.47m, Calculated FoV: 59.59 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000028.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_102.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_102.png
#
# Processing row 27 (Building ID: 10, OSM ID: 182136612)
#   Distance (XY): 6.67m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.28, Raw Pitch: 2.15, Final Pitch: 2.15
#   Facade Length: 10.36m, Calculated FoV: 87.03 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000026.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_10.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_10.png
#
# Processing row 28 (Building ID: 72, OSM ID: 182137474)
#   Distance (XY): 6.59m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.17, Raw Pitch: 2.17, Final Pitch: 2.17
#   Facade Length: 4.98m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000023.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_72.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_72.png
#
# Processing row 29 (Building ID: 132, OSM ID: 182138214)
#   Distance (XY): 6.60m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.58, Raw Pitch: 2.17, Final Pitch: 2.17
#   Facade Length: 5.00m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000021.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_132.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_132.png
#
# Processing row 30 (Building ID: 120, OSM ID: 182138080)
#   Distance (XY): 6.73m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.04, Raw Pitch: 2.13, Final Pitch: 2.13
#   Facade Length: 6.98m, Calculated FoV: 63.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000019.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_120.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_120.png
#
# Processing row 31 (Building ID: 84, OSM ID: 182137642)
#   Distance (XY): 6.77m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 250.22, Raw Pitch: 2.11, Final Pitch: 2.11
#   Facade Length: 4.05m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000018.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_84.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_84.png
#
# Processing row 32 (Building ID: 115, OSM ID: 182137975)
#   Distance (XY): 6.79m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.29, Raw Pitch: 2.11, Final Pitch: 2.11
#   Facade Length: 5.48m, Calculated FoV: 50.52 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000016.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_115.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_115.png
#
# Processing row 33 (Building ID: 47, OSM ID: 182136877)
#   Distance (XY): 6.80m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.29, Raw Pitch: 2.10, Final Pitch: 2.10
#   Facade Length: 5.48m, Calculated FoV: 50.45 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000014.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_47.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_47.png
#
# Processing row 34 (Building ID: 47, OSM ID: 182136877)
#   Distance (XY): 6.94m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 246.62, Raw Pitch: 2.06, Final Pitch: 2.06
#   Facade Length: 14.16m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000011.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_47A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_47A.png
#
# Processing row 35 (Building ID: 8, OSM ID: 182136607)
#   Distance (XY): 6.99m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 246.52, Raw Pitch: 2.05, Final Pitch: 2.05
#   Facade Length: 13.49m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000006.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_8.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_8.png
#
# Processing row 36 (Building ID: 62, OSM ID: 182137189)
#   Distance (XY): 6.65m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 246.55, Raw Pitch: 2.15, Final Pitch: 2.15
#   Facade Length: 4.09m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000003.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_62.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_62.png
#
# Processing row 37 (Building ID: 74, OSM ID: 182137491)
#   Distance (XY): 4.15m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.37, Raw Pitch: 3.45, Final Pitch: 3.45
#   Facade Length: 6.46m, Calculated FoV: 87.17 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000002.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_74.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_74.png
#
# Processing row 38 (Building ID: 162, OSM ID: 2427027)
#   Distance (XY): 4.48m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.55, Raw Pitch: 3.19, Final Pitch: 3.19
#   Facade Length: 12.36m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000005.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_162.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_162.png
#
# Processing row 39 (Building ID: 69, OSM ID: 182137376)
#   Distance (XY): 4.34m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.44, Raw Pitch: 3.30, Final Pitch: 3.30
#   Facade Length: 4.67m, Calculated FoV: 65.10 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000008.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_69.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_69.png
#
# Processing row 40 (Building ID: 136, OSM ID: 182138243)
#   Distance (XY): 4.22m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.16, Raw Pitch: 3.39, Final Pitch: 3.39
#   Facade Length: 4.75m, Calculated FoV: 67.59 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000010.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_136.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_136.png
#
# Processing row 41 (Building ID: 1, OSM ID: 182136570)
#   Distance (XY): 4.07m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.56, Raw Pitch: 3.51, Final Pitch: 3.51
#   Facade Length: 6.66m, Calculated FoV: 90.38 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000012.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_1.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_1.png
#
# Processing row 42 (Building ID: 11, OSM ID: 182136621)
#   Distance (XY): 3.95m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.53, Raw Pitch: 3.62, Final Pitch: 3.62
#   Facade Length: 9.19m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000014.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_11.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_11.png
#
# Processing row 43 (Building ID: 2, OSM ID: 182136574)
#   Distance (XY): 3.95m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.13, Raw Pitch: 3.62, Final Pitch: 3.62
#   Facade Length: 3.73m, Calculated FoV: 58.06 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000016.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_2.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_2.png
#
# Processing row 44 (Building ID: 119, OSM ID: 182138057)
#   Distance (XY): 3.98m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.50, Raw Pitch: 3.59, Final Pitch: 3.59
#   Facade Length: 5.56m, Calculated FoV: 80.33 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000018.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_119.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_119.png
#
# Processing row 45 (Building ID: 71, OSM ID: 182137460)
#   Distance (XY): 4.14m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.69, Raw Pitch: 3.45, Final Pitch: 3.45
#   Facade Length: 4.87m, Calculated FoV: 70.01 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000020.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_71.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_71.png
#
# Processing row 46 (Building ID: 166, OSM ID: 2427043)
#   Distance (XY): 4.31m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.17, Raw Pitch: 3.32, Final Pitch: 3.32
#   Facade Length: 5.65m, Calculated FoV: 76.45 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000021.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_166.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_166.png
#
# Processing row 47 (Building ID: 110, OSM ID: 182137952)
#   Distance (XY): 4.54m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 67.15, Raw Pitch: 3.15, Final Pitch: 3.15
#   Facade Length: 3.39m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000023.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_110.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_110.png
#
# Processing row 48 (Building ID: 26, OSM ID: 182136738)
#   Distance (XY): 4.23m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 71.16, Raw Pitch: 3.38, Final Pitch: 3.38
#   Facade Length: 5.61m, Calculated FoV: 77.24 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000024.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_26.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_26.png
#
# Processing row 49 (Building ID: 182, OSM ID: 2427083)
#   Distance (XY): 3.64m
#   View Angle to Facade Normal: 0.30 deg
#   Calculated Yaw: 61.65, Raw Pitch: 3.93, Final Pitch: 3.93
#   Facade Length: 2.27m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000026.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_182.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_182.png
#
# Processing row 50 (Building ID: 182, OSM ID: 2427083)
#   Distance (XY): 3.38m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 64.70, Raw Pitch: 4.24, Final Pitch: 4.24
#   Facade Length: 12.72m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000028.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_182A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_182A.png
#
# Processing row 51 (Building ID: 103, OSM ID: 182137901)
#   Distance (XY): 3.48m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 64.76, Raw Pitch: 4.11, Final Pitch: 4.11
#   Facade Length: 3.53m, Calculated FoV: 61.81 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000031.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_103.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_103.png
#
# Processing row 52 (Building ID: 101, OSM ID: 182137853)
#   Distance (XY): 3.60m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 64.85, Raw Pitch: 3.97, Final Pitch: 3.97
#   Facade Length: 3.66m, Calculated FoV: 62.01 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000032.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_101.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_101.png
#
# Processing row 53 (Building ID: 87, OSM ID: 182137654)
#   Distance (XY): 3.70m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 67.57, Raw Pitch: 3.87, Final Pitch: 3.87
#   Facade Length: 3.78m, Calculated FoV: 62.28 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000033.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_87.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_87.png
#
# Processing row 54 (Building ID: 78, OSM ID: 182137556)
#   Distance (XY): 3.68m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 68.24, Raw Pitch: 3.89, Final Pitch: 3.89
#   Facade Length: 3.37m, Calculated FoV: 56.63 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000034.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_78.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_78.png
#
# Processing row 55 (Building ID: 60, OSM ID: 182137110)
#   Distance (XY): 3.44m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 68.83, Raw Pitch: 4.16, Final Pitch: 4.16
#   Facade Length: 5.02m, Calculated FoV: 83.07 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000036.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_60.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_60.png
#
# Processing row 56 (Building ID: 95, OSM ID: 182137766)
#   Distance (XY): 3.31m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 67.80, Raw Pitch: 4.31, Final Pitch: 4.31
#   Facade Length: 3.45m, Calculated FoV: 63.24 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000037.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_95.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_95.png
#
# Processing row 57 (Building ID: 90, OSM ID: 182137721)
#   Distance (XY): 3.16m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 68.25, Raw Pitch: 4.53, Final Pitch: 4.53
#   Facade Length: 4.23m, Calculated FoV: 77.84 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000038.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_90.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_90.png
#
# Processing row 58 (Building ID: 114, OSM ID: 182137972)
#   Distance (XY): 2.82m
# Skipping: Distance 2.82m out of range [3.0, 25.0].
#
# Processing row 59 (Building ID: 96, OSM ID: 182137768)
#   Distance (XY): 2.71m
# Skipping: Distance 2.71m out of range [3.0, 25.0].
#
# Processing row 60 (Building ID: 184, OSM ID: 2427096)
#   Distance (XY): 50.89m
# Skipping: Distance 50.89m out of range [3.0, 25.0].
#
# Processing row 61 (Building ID: 160, OSM ID: 2427022)
#   Distance (XY): 50.99m
# Skipping: Distance 50.99m out of range [3.0, 25.0].
#
# Processing row 62 (Building ID: 137, OSM ID: 182138244)
#   Distance (XY): 51.01m
# Skipping: Distance 51.01m out of range [3.0, 25.0].
#
# Processing row 63 (Building ID: 3, OSM ID: 182136591)
#   Distance (XY): 50.92m
# Skipping: Distance 50.92m out of range [3.0, 25.0].
#
# Processing row 64 (Building ID: 122, OSM ID: 182138104)
#   Distance (XY): 50.64m
# Skipping: Distance 50.64m out of range [3.0, 25.0].
#
# Processing row 65 (Building ID: 163, OSM ID: 2427028)
#   Distance (XY): 50.07m
# Skipping: Distance 50.07m out of range [3.0, 25.0].
#
# Processing row 66 (Building ID: 163, OSM ID: 2427028)
#   Distance (XY): 51.56m
# Skipping: Distance 51.56m out of range [3.0, 25.0].
#
# Processing row 67 (Building ID: 171, OSM ID: 2427060)
#   Distance (XY): 52.06m
# Skipping: Distance 52.06m out of range [3.0, 25.0].
#
# Processing row 68 (Building ID: 37, OSM ID: 182136824)
#   Distance (XY): 5.32m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.94, Raw Pitch: 2.69, Final Pitch: 2.69
#   Facade Length: 16.09m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000063.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_37.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_37.png
#
# Processing row 69 (Building ID: 37, OSM ID: 182136824)
#   Distance (XY): 5.58m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 249.60, Raw Pitch: 2.56, Final Pitch: 2.56
#   Facade Length: 9.13m, Calculated FoV: 90.32 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000059.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_37A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_37A.png
#
# Processing row 70 (Building ID: 61, OSM ID: 182137172)
#   Distance (XY): 5.81m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 246.61, Raw Pitch: 2.46, Final Pitch: 2.46
#   Facade Length: 8.04m, Calculated FoV: 79.70 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000056.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_61.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_61.png
#
# Processing row 71 (Building ID: 163, OSM ID: 2427028)
#   Distance (XY): 20.14m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 244.16, Raw Pitch: 0.71, Final Pitch: 0.71
#   Facade Length: 9.03m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000053.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_163.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_163.png
#
# Processing row 72 (Building ID: 128, OSM ID: 182138186)
#   Distance (XY): 6.89m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.03, Raw Pitch: 2.08, Final Pitch: 2.08
#   Facade Length: 19.10m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000048.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_128.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_128.png
#
# Processing row 73 (Building ID: 81, OSM ID: 182137583)
#   Distance (XY): 6.92m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 247.89, Raw Pitch: 2.07, Final Pitch: 2.07
#   Facade Length: 15.92m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000042.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_81.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_81.png
#
# Processing row 74 (Building ID: 184, OSM ID: 2427096)
#   Distance (XY): 6.47m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.88, Raw Pitch: 2.21, Final Pitch: 2.21
#   Facade Length: 26.78m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000035.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_184.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_184.png
#
# Processing row 75 (Building ID: 126, OSM ID: 182138152)
#   Distance (XY): 6.84m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.27, Raw Pitch: 2.09, Final Pitch: 2.09
#   Facade Length: 4.33m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000030.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_126.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_126.png
#
# Processing row 76 (Building ID: 138, OSM ID: 182138247)
#   Distance (XY): 6.73m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 246.14, Raw Pitch: 2.13, Final Pitch: 2.13
#   Facade Length: 6.49m, Calculated FoV: 59.21 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000028.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_138.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_138.png
#
# Processing row 77 (Building ID: 21, OSM ID: 182136704)
#   Distance (XY): 6.12m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.77, Raw Pitch: 2.34, Final Pitch: 2.34
#   Facade Length: 10.35m, Calculated FoV: 92.47 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000025.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_21.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_21.png
#
# Processing row 78 (Building ID: 56, OSM ID: 182136995)
#   Distance (XY): 5.83m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.47, Raw Pitch: 2.45, Final Pitch: 2.45
#   Facade Length: 3.02m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000023.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_56.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_56.png
#
# Processing row 79 (Building ID: 22, OSM ID: 182136706)
#   Distance (XY): 6.07m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.96, Raw Pitch: 2.36, Final Pitch: 2.36
#   Facade Length: 7.05m, Calculated FoV: 69.29 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000021.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_22.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_22.png
#
# Processing row 80 (Building ID: 183, OSM ID: 2427090)
#   Distance (XY): 6.32m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.91, Raw Pitch: 2.27, Final Pitch: 2.27
#   Facade Length: 21.43m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000017.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_183.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_183.png
#
# Processing row 81 (Building ID: 44, OSM ID: 182136869)
#   Distance (XY): 6.01m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.32, Raw Pitch: 2.38, Final Pitch: 2.38
#   Facade Length: 17.06m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000010.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_44.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_44.png
#
# Processing row 82 (Building ID: 105, OSM ID: 182137927)
#   Distance (XY): 5.78m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.25, Raw Pitch: 2.47, Final Pitch: 2.47
#   Facade Length: 6.13m, Calculated FoV: 64.18 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000006.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_105.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_105.png
#
# Processing row 83 (Building ID: 117, OSM ID: 182138001)
#   Distance (XY): 5.83m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.36, Raw Pitch: 2.46, Final Pitch: 2.46
#   Facade Length: 12.58m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000003.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_117.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_117.png
#
# Processing row 84 (Building ID: 42, OSM ID: 182136862)
#   Distance (XY): 24.01m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 245.17, Raw Pitch: 0.60, Final Pitch: 0.60
#   Facade Length: 5.65m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\117\pano_000117_000003.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_42.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_42.png
#
# Processing row 85 (Building ID: 42, OSM ID: 182136862)
#   Distance (XY): 28.81m
# Skipping: Distance 28.81m out of range [3.0, 25.0].
#
# Processing row 86 (Building ID: 42, OSM ID: 182136862)
#   Distance (XY): 35.40m
# Skipping: Distance 35.40m out of range [3.0, 25.0].
#
# Processing row 87 (Building ID: 42, OSM ID: 182136862)
#   Distance (XY): 46.40m
# Skipping: Distance 46.40m out of range [3.0, 25.0].
#
# Processing row 88 (Building ID: 44, OSM ID: 182136869)
#   Distance (XY): 47.78m
# Skipping: Distance 47.78m out of range [3.0, 25.0].
#
# Processing row 89 (Building ID: 183, OSM ID: 2427090)
#   Distance (XY): 49.48m
# Skipping: Distance 49.48m out of range [3.0, 25.0].
#
# Processing row 90 (Building ID: 170, OSM ID: 2427053)
#   Distance (XY): 50.01m
# Skipping: Distance 50.01m out of range [3.0, 25.0].
#
# Processing row 91 (Building ID: 9, OSM ID: 182136608)
#   Distance (XY): 50.22m
# Skipping: Distance 50.22m out of range [3.0, 25.0].
#
# Processing row 92 (Building ID: 130, OSM ID: 182138195)
#   Distance (XY): 50.32m
# Skipping: Distance 50.32m out of range [3.0, 25.0].
#
# Processing row 93 (Building ID: 88, OSM ID: 182137656)
#   Distance (XY): 50.73m
# Skipping: Distance 50.73m out of range [3.0, 25.0].
#
# Processing row 94 (Building ID: 126, OSM ID: 182138152)
#   Distance (XY): 51.21m
# Skipping: Distance 51.21m out of range [3.0, 25.0].
#
# Processing row 95 (Building ID: 43, OSM ID: 182136865)
#   Distance (XY): 4.77m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 70.68, Raw Pitch: 3.00, Final Pitch: 3.00
#   Facade Length: 20.60m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000029.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_43.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_43.png
#
# Processing row 96 (Building ID: 45, OSM ID: 182136870)
#   Distance (XY): 4.32m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 71.05, Raw Pitch: 3.31, Final Pitch: 3.31
#   Facade Length: 39.65m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000039.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_45.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_45.png
#
# Processing row 97 (Building ID: 129, OSM ID: 182138192)
#   Distance (XY): 3.93m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 69.80, Raw Pitch: 3.64, Final Pitch: 3.64
#   Facade Length: 9.06m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000047.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_129.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_129.png
#
# Processing row 98 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 3.63m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 69.65, Raw Pitch: 3.94, Final Pitch: 3.94
#   Facade Length: 54.06m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000058.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_49.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_49.png
#
# Processing row 99 (Building ID: 142, OSM ID: 182138273)
#   Distance (XY): 3.32m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 69.75, Raw Pitch: 4.30, Final Pitch: 4.30
#   Facade Length: 13.19m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000069.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_142.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_142.png
#
# Processing row 100 (Building ID: 142, OSM ID: 182138273)
#   Distance (XY): 17.65m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 78.00, Raw Pitch: 0.81, Final Pitch: 0.81
#   Facade Length: 11.12m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000070.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_142A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_142A.png
#
# Processing row 101 (Building ID: 142, OSM ID: 182138273)
#   Distance (XY): 19.27m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 74.35, Raw Pitch: 0.74, Final Pitch: 0.74
#   Facade Length: 2.34m, Calculated FoV: 50.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000067.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_142B.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_142B.png
#
# Processing row 102 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 25.07m
# Skipping: Distance 25.07m out of range [3.0, 25.0].
#
# Processing row 103 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 29.23m
# Skipping: Distance 29.23m out of range [3.0, 25.0].
#
# Processing row 104 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 29.69m
# Skipping: Distance 29.69m out of range [3.0, 25.0].
#
# Processing row 105 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 29.94m
# Skipping: Distance 29.94m out of range [3.0, 25.0].
#
# Processing row 106 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 30.09m
# Skipping: Distance 30.09m out of range [3.0, 25.0].
#
# Processing row 107 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 14.36m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 72.40, Raw Pitch: 1.00, Final Pitch: 1.00
#   Facade Length: 37.63m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000058.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_49A.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_49A.png
#
# Processing row 108 (Building ID: 49, OSM ID: 182136884)
#   Distance (XY): 42.36m
# Skipping: Distance 42.36m out of range [3.0, 25.0].
#
# Processing row 109 (Building ID: 75, OSM ID: 182137510)
#   Distance (XY): 43.01m
# Skipping: Distance 43.01m out of range [3.0, 25.0].
#
# Processing row 110 (Building ID: 45, OSM ID: 182136870)
#   Distance (XY): 44.04m
# Skipping: Distance 44.04m out of range [3.0, 25.0].
#
# Processing row 111 (Building ID: 45, OSM ID: 182136870)
#   Distance (XY): 48.54m
# Skipping: Distance 48.54m out of range [3.0, 25.0].
#
# Processing row 112 (Building ID: 45, OSM ID: 182136870)
#   Distance (XY): 47.01m
# Skipping: Distance 47.01m out of range [3.0, 25.0].
#
# Processing row 113 (Building ID: 43, OSM ID: 182136865)
#   Distance (XY): 40.91m
# Skipping: Distance 40.91m out of range [3.0, 25.0].
#
# Processing row 114 (Building ID: 43, OSM ID: 182136865)
#   Distance (XY): 33.15m
# Skipping: Distance 33.15m out of range [3.0, 25.0].
#
# Processing row 115 (Building ID: 43, OSM ID: 182136865)
#   Distance (XY): 38.96m
# Skipping: Distance 38.96m out of range [3.0, 25.0].
#
# Processing row 116 (Building ID: 124, OSM ID: 182138144)
#   Distance (XY): 34.59m
# Skipping: Distance 34.59m out of range [3.0, 25.0].
#
# Processing row 117 (Building ID: 30, OSM ID: 182136766)
#   Distance (XY): 28.22m
# Skipping: Distance 28.22m out of range [3.0, 25.0].
#
# Processing row 118 (Building ID: 30, OSM ID: 182136766)
#   Distance (XY): 29.67m
# Skipping: Distance 29.67m out of range [3.0, 25.0].
#
# Processing row 119 (Building ID: 30, OSM ID: 182136766)
#   Distance (XY): 39.28m
# Skipping: Distance 39.28m out of range [3.0, 25.0].
#
# Processing row 120 (Building ID: 30, OSM ID: 182136766)
#   Distance (XY): 43.81m
# Skipping: Distance 43.81m out of range [3.0, 25.0].
#
# Processing row 121 (Building ID: 125, OSM ID: 182138149)
#   Distance (XY): 48.17m
# Skipping: Distance 48.17m out of range [3.0, 25.0].
#
# Processing row 122 (Building ID: 178, OSM ID: 2427076)
#   Distance (XY): 39.82m
# Skipping: Distance 39.82m out of range [3.0, 25.0].
#
# Processing row 123 (Building ID: 140, OSM ID: 182138256)
#   Distance (XY): 39.99m
# Skipping: Distance 39.99m out of range [3.0, 25.0].
#
# Processing row 124 (Building ID: 127, OSM ID: 182138164)
#   Distance (XY): 4.58m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 66.15, Raw Pitch: 3.12, Final Pitch: 3.12
#   Facade Length: 10.65m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000011.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_127.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_127.png
#
# Processing row 125 (Building ID: 178, OSM ID: 2427076)
#   Distance (XY): 5.08m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 65.95, Raw Pitch: 2.82, Final Pitch: 2.82
#   Facade Length: 10.89m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000015.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_178.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_178.png
#
# Processing row 126 (Building ID: 164, OSM ID: 2427035)
#   Distance (XY): 5.18m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 72.91, Raw Pitch: 2.77, Final Pitch: 2.77
#   Facade Length: 6.60m, Calculated FoV: 74.83 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000018.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_164.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_164.png
#
# Processing row 127 (Building ID: 30, OSM ID: 182136766)
#   Distance (XY): 5.14m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 70.80, Raw Pitch: 2.78, Final Pitch: 2.78
#   Facade Length: 11.97m, Calculated FoV: 100.00 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000021.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_30.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_30.png
#
# Processing row 128 (Building ID: 124, OSM ID: 182138144)
#   Distance (XY): 5.00m
#   View Angle to Facade Normal: 0.00 deg
#   Calculated Yaw: 70.76, Raw Pitch: 2.86, Final Pitch: 2.86
#   Facade Length: 9.47m, Calculated FoV: 99.96 deg
#   Loaded image: ../data/PANO_new/B\116\pano_000116_000024.jpg
#   Saving perspective image to: ../data/Street_view/Output_images_REVISED/Building_124.png
#   Warning: Failed to save image ../data/Street_view/Output_images_REVISED/Building_124.png
#
# Updating GeoDataFrame with output filenames...
# Saving updated GeoDataFrame to: data/Street_view/Preprocessed_with_filenames_REVISED.geojson
# GeoDataFrame saved successfully.
#
# Processing finished.
