# %%
import numpy as np
from classes.PanoramaProcessor import PanoramaProcessor
import sys
import os
project_path = r"c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama"
sys.path.append(project_path)
from s3_library.S3Client import S3Client


def main():
    """
    Main function that configures and starts the panorama processor.
    """
    # Configuration
    root = 'rectification/'
    country_city = 'results/'
    plot_redundant = True
    save_directly = False
    new_count = 5
    
    # New parameters for the GeoDataFrame
    geodataframe_path = 'geodataframe/results/Enhanced_facades_for_extraction_718_facades.geojson'
    images_base_path = '2025/'

    s3_client = S3Client()

    # Initialize and start the processor
    processor = PanoramaProcessor(
        root=root,
        country_city=country_city,
        plot_redundant=plot_redundant,
        save_directly=save_directly,
        new_count=new_count,
        geodataframe_path=geodataframe_path,
        images_base_path=images_base_path,
        s3_client=s3_client
    )
    
    processor.process_all_panoramas()


if __name__ == "__main__":
    # Uncomment to use a fixed seed for reproducibility
    # np.random.seed(1)
    main()
# Out:
# <CDLL 'c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\histograms\libmnf_modes.dll', handle 7fff22b10000 at 0x19bfbcb7f80>
# Found 718 images from geodataframe
# Trovate 718 immagini da elaborare
#
# [1/718] Elaborazione di: 2025/sudest2/pano/45/pano_000045_000072.jpg
# 2025/sudest2/pano/45/pano_000045_000072.jpg
# STEP - Tentativo di caricamento immagine da S3: 2025/sudest2/pano/45/pano_000045_000072.jpg
# DEBUG - Immagine caricata: (8192, 4096)
# STEP - Conversione in array NumPy completata: forma (4096, 8192, 3)
# STEP - Configurazione cartelle temporanee
# STEP - Cartelle temporanee configurate
# STEP - Inizio processamento tile
# STEP - Processamento tile 1/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 1 processato con successo
# STEP - Processamento tile 2/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 2 processato con successo
# STEP - Processamento tile 3/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 3 processato con successo
# STEP - Processamento tile 4/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 4 processato con successo
# STEP - Directory temporanea eliminata: C:\Users\RAIMON~1\AppData\Local\Temp\s3_tiles_k3csmrbi
# STEP - Processamento tile completato
# Deleted 4 objects with prefix 'rectification/results/tmp/1/1/' from bucket 'data'
# STEP - Calcolo punti zenit
# Saved visualization to S3: data/rectification/all_vp_and_hl_color.jpg
# Saved visualization to S3: data/rectification/all_vp_and_hl_bi.jpg
# STEP - Calcolo consensus e rectificazione
# Saved visualization locally to: rectification/consensus_zp_hvps.jpg
# Saved visualization to S3: data/rectification/consensus_hvps_center_on_panoramas.jpg
# STEP - Calcolo consensus e rectificazione completato
# STEP - Rendering facades
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Rendering facades completato
#
# [2/718] Elaborazione di: 2025/sudest2/pano/48/pano_000048_000041.jpg
# 2025/sudest2/pano/48/pano_000048_000041.jpg
# STEP - Tentativo di caricamento immagine da S3: 2025/sudest2/pano/48/pano_000048_000041.jpg
# DEBUG - Immagine caricata: (8192, 4096)
# STEP - Conversione in array NumPy completata: forma (4096, 8192, 3)
# STEP - Configurazione cartelle temporanee
# STEP - Cartelle temporanee configurate
# STEP - Inizio processamento tile
# STEP - Processamento tile 1/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\z_predict.py:20: RuntimeWarning: divide by zero encountered in divide
#   lines_tilt_ortho = np.arctan(-lines_homo[1,:] / lines_homo[0,:])*180 / np.pi
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 1 processato con successo
# STEP - Processamento tile 2/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 2 processato con successo
# STEP - Processamento tile 3/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 3 processato con successo
# STEP - Processamento tile 4/4
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
# STEP - Tile 4 processato con successo
# STEP - Directory temporanea eliminata: C:\Users\RAIMON~1\AppData\Local\Temp\s3_tiles_426t6jt3
# STEP - Processamento tile completato
# Deleted 4 objects with prefix 'rectification/results/tmp/1/1/' from bucket 'data'
# STEP - Calcolo punti zenit
# Saved visualization to S3: data/rectification/all_vp_and_hl_color.jpg
# Saved visualization to S3: data/rectification/all_vp_and_hl_bi.jpg
# STEP - Calcolo consensus e rectificazione
# Saved visualization locally to: rectification/consensus_zp_hvps.jpg
# Saved visualization to S3: data/rectification/consensus_hvps_center_on_panoramas.jpg
# STEP - Calcolo consensus e rectificazione completato
# STEP - Rendering facades
# c:\Users\RaimondoReggio\OneDrive - Net Service S.p.A\Desktop\GitHub\hammon-WP4\Street_view\rectified_facades_extraction_from_panorama\rectification\vanishing_points_utils\vp_predict.py:54: RuntimeWarning: invalid value encountered in sqrt
#   d2 = np.sqrt(rho2 * rho2 - 1)
